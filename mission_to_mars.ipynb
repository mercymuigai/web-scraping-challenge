# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %% [markdown]
# NASA Mars News

# %%
url = 'https://mars.nasa.gov/news/'
browser.visit(url)

# %%
html = browser.html

#getting the soup object
soup = BeautifulSoup(html, 'html.parser')

#scrapping for the news title
article = soup.find_all('div', class_='content_title')[1]
title = article.text

print(title)
# Out:
# Q&A with the Student Who Named Ingenuity, NASA's Mars Helicopter

# %%
#scrapping for the paragraph text

paragraph  = soup.find('div', class_='article_teaser_body').text

print(paragraph)
# Out:
# As a longtime fan of space exploration, Vaneeza Rupani appreciates the creativity and collaboration involved with trying to fly on another planet.

# %% [markdown]
# JPL Mars Space Images - Featured Image

# %%
# #url for the scrape
url_image = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'

# %%
browser.visit(url_image)

html= browser.html

#getting the soup object
soup = BeautifulSoup(html, 'html.parser')
# soup

# %%
#using soup to get featured_image

img = soup.find_all("a", class_="fancybox")
print(img)
# Out:
# [<a class="button fancybox" data-description="This image from NASA's Terra spacecraft shows Poyang Lake, which was once China's largest freshwater lake." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA20263_ip.jpg" data-link="/spaceimages/details.php?id=PIA20263" data-title="Poyang Lake, China" id="full_image">
# 					FULL IMAGE
# 				  </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of Orson Welles Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23857_hires.jpg" data-link="/spaceimages/details.php?id=PIA23857" data-thumbnail="/spaceimages/images/wallpaper/PIA23857-640x350.jpg" data-title="Orson Welles Crater Chaos">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 28, 2020</h3>
# <div class="item_tease_overlay">Orson Welles Crater Chaos</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Orson Welles Crater Chaos" class="thumb" src="/spaceimages/images/wallpaper/PIA23857-640x350.jpg" title="Orson Welles Crater Chaos"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 28, 2020</div>
# <div class="content_title">
# 										  Orson Welles Crater Chaos
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of the floor of Orson Welles Crater.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Sirenum Fossae. The linear depression was created by tectonic forces stretching the surface." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23856_hires.jpg" data-link="/spaceimages/details.php?id=PIA23856" data-thumbnail="/spaceimages/images/wallpaper/PIA23856-640x350.jpg" data-title="Sirenum Fossae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 27, 2020</h3>
# <div class="item_tease_overlay">Sirenum Fossae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Sirenum Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23856-640x350.jpg" title="Sirenum Fossae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 27, 2020</div>
# <div class="content_title">
# 										  Sirenum Fossae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of Sirenum Fossae. The linear depression was created by tectonic forces stretching the surface.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a portion of Kasei Valles. Kasei Valles is one of the largest outflow channel systems on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23845_hires.jpg" data-link="/spaceimages/details.php?id=PIA23845" data-thumbnail="/spaceimages/images/wallpaper/PIA23845-640x350.jpg" data-title="Kasei Valles">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 24, 2020</h3>
# <div class="item_tease_overlay">Kasei Valles</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Kasei Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23845-640x350.jpg" title="Kasei Valles"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 24, 2020</div>
# <div class="content_title">
# 										  Kasei Valles
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a portion of Kasei Valles. Kasei Valles is one of the largest outflow channel systems on Mars.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows linear depressions, part of Sirenum Fossae. These depressions are called graben, which form by the down drop of material between two parallel faults." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23844_hires.jpg" data-link="/spaceimages/details.php?id=PIA23844" data-thumbnail="/spaceimages/images/wallpaper/PIA23844-640x350.jpg" data-title="Sirenum Fossae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 23, 2020</h3>
# <div class="item_tease_overlay">Sirenum Fossae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Sirenum Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23844-640x350.jpg" title="Sirenum Fossae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 23, 2020</div>
# <div class="content_title">
# 										  Sirenum Fossae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows linear depressions, part of Sirenum Fossae. These depressions are called graben, which form by the down drop of material between two parallel faults.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Ares Vallis. Ares Vallis is a large channel that arises in Iani Chaos, passes through Margaritifer Terra, and then empties into Chryse Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23843_hires.jpg" data-link="/spaceimages/details.php?id=PIA23843" data-thumbnail="/spaceimages/images/wallpaper/PIA23843-640x350.jpg" data-title="Ares Vallis">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 22, 2020</h3>
# <div class="item_tease_overlay">Ares Vallis</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Ares Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23843-640x350.jpg" title="Ares Vallis"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 22, 2020</div>
# <div class="content_title">
# 										  Ares Vallis
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of Ares Vallis. Ares Vallis is a large channel that arises in Iani Chaos, passes through Margaritifer Terra, and then empties into Chryse Planitia.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows several windstreaks on lava plains southwest of Arsia Mons. The extensive lava flow field is called Daedalia Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23842_hires.jpg" data-link="/spaceimages/details.php?id=PIA23842" data-thumbnail="/spaceimages/images/wallpaper/PIA23842-640x350.jpg" data-title="Daedalia Planum Windstreaks">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 21, 2020</h3>
# <div class="item_tease_overlay">Daedalia Planum Windstreaks</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Daedalia Planum Windstreaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23842-640x350.jpg" title="Daedalia Planum Windstreaks"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 21, 2020</div>
# <div class="content_title">
# 										  Daedalia Planum Windstreaks
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows several windstreaks on lava plains southwest of Arsia Mons. The extensive lava flow field is called Daedalia Planum.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the summit of Ascraeus Mons. Ascraeus Mons is the northernmost of the three aligned Tharsis volcanoes." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23841_hires.jpg" data-link="/spaceimages/details.php?id=PIA23841" data-thumbnail="/spaceimages/images/wallpaper/PIA23841-640x350.jpg" data-title="Ascraeus Mons">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 20, 2020</h3>
# <div class="item_tease_overlay">Ascraeus Mons</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Ascraeus Mons" class="thumb" src="/spaceimages/images/wallpaper/PIA23841-640x350.jpg" title="Ascraeus Mons"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 20, 2020</div>
# <div class="content_title">
# 										  Ascraeus Mons
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows the summit of Ascraeus Mons. Ascraeus Mons is the northernmost of the three aligned Tharsis volcanoes.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 29, 2020 by NASAs Mars Reconnaissance Orbiter, shows a pitted, blocky surface, but also more unusually, it has contorted, irregular features." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23855_hires.jpg" data-link="/spaceimages/details.php?id=PIA23855" data-thumbnail="/spaceimages/images/wallpaper/PIA23855-640x350.jpg" data-title="Disrupted Sediments in Acidalia Planitia">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">Disrupted Sediments in Acidalia Planitia</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Disrupted Sediments in Acidalia Planitia" class="thumb" src="/spaceimages/images/wallpaper/PIA23855-640x350.jpg" title="Disrupted Sediments in Acidalia Planitia"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  Disrupted Sediments in Acidalia Planitia
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 29, 2020 by NASAs Mars Reconnaissance Orbiter, shows a pitted, blocky surface, but also more unusually, it has contorted, irregular features.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 27, 2020 by NASAs Mars Reconnaissance Orbiter, shows a couple of dark lineations on the equator-facing wall of this impact crater that resemble small recurring slope lineae (RSL)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23854_hires.jpg" data-link="/spaceimages/details.php?id=PIA23854" data-thumbnail="/spaceimages/images/wallpaper/PIA23854-640x350.jpg" data-title="Keeping a Watchful Eye">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">Keeping a Watchful Eye</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Keeping a Watchful Eye" class="thumb" src="/spaceimages/images/wallpaper/PIA23854-640x350.jpg" title="Keeping a Watchful Eye"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  Keeping a Watchful Eye
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 27, 2020 by NASAs Mars Reconnaissance Orbiter, shows a couple of dark lineations on the equator-facing wall of this impact crater that resemble small recurring slope lineae (RSL).
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 19, 2020 by NASAs Mars Reconnaissance Orbiter, shows gullies in the sand dunes of Matara Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23853_hires.jpg" data-link="/spaceimages/details.php?id=PIA23853" data-thumbnail="/spaceimages/images/wallpaper/PIA23853-640x350.jpg" data-title="An Active Gully in Matara Crater">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">An Active Gully in Matara Crater</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="An Active Gully in Matara Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23853-640x350.jpg" title="An Active Gully in Matara Crater"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  An Active Gully in Matara Crater
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 19, 2020 by NASAs Mars Reconnaissance Orbiter, shows gullies in the sand dunes of Matara Crater.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 18, 2020 by NASAs Mars Reconnaissance Orbiter, shows two different targets at once, a geologically-young crater and a small even younger one." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23852_hires.jpg" data-link="/spaceimages/details.php?id=PIA23852" data-thumbnail="/spaceimages/images/wallpaper/PIA23852-640x350.jpg" data-title="Two Young Craters">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">Two Young Craters</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Two Young Craters" class="thumb" src="/spaceimages/images/wallpaper/PIA23852-640x350.jpg" title="Two Young Craters"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  Two Young Craters
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 18, 2020 by NASAs Mars Reconnaissance Orbiter, shows two different targets at once, a geologically-young crater and a small even younger one.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a small portion of Daedalia Planum. Daedalia Planum is an immense lava flow field that originates at Arsia Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23840_hires.jpg" data-link="/spaceimages/details.php?id=PIA23840" data-thumbnail="/spaceimages/images/wallpaper/PIA23840-640x350.jpg" data-title="Daedalia Planum">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 17, 2020</h3>
# <div class="item_tease_overlay">Daedalia Planum</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Daedalia Planum" class="thumb" src="/spaceimages/images/wallpaper/PIA23840-640x350.jpg" title="Daedalia Planum"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 17, 2020</div>
# <div class="content_title">
# 										  Daedalia Planum
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a small portion of Daedalia Planum. Daedalia Planum is an immense lava flow field that originates at Arsia Mons.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a small section of Shalbatana Vallis." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23839_hires.jpg" data-link="/spaceimages/details.php?id=PIA23839" data-thumbnail="/spaceimages/images/wallpaper/PIA23839-640x350.jpg" data-title="Shalbatana Vallis">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 16, 2020</h3>
# <div class="item_tease_overlay">Shalbatana Vallis</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Shalbatana Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23839-640x350.jpg" title="Shalbatana Vallis"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 16, 2020</div>
# <div class="content_title">
# 										  Shalbatana Vallis
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a small section of Shalbatana Vallis.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows several windstreaks located on the volcanic plains of Daedalia Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23838_hires.jpg" data-link="/spaceimages/details.php?id=PIA23838" data-thumbnail="/spaceimages/images/wallpaper/PIA23838-640x350.jpg" data-title="Daedalia Planum Windstreaks">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 15, 2020</h3>
# <div class="item_tease_overlay">Daedalia Planum Windstreaks</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Daedalia Planum Windstreaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23838-640x350.jpg" title="Daedalia Planum Windstreaks"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 15, 2020</div>
# <div class="content_title">
# 										  Daedalia Planum Windstreaks
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows several windstreaks located on the volcanic plains of Daedalia Planum.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="Members of NASAs Curiosity Mars rover mission team photographed themselves on March 20, 2020, the first day the entire mission team worked remotely from home." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23773_hires.jpg" data-link="/spaceimages/details.php?id=PIA23773" data-thumbnail="/spaceimages/images/wallpaper/PIA23773-640x350.jpg" data-title="Curiosity" s="" team="" teleworks'="">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 14, 2020</h3>
# <div class="item_tease_overlay">Curiosity's Team Teleworks</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Curiosity" class="thumb" s="" src="/spaceimages/images/wallpaper/PIA23773-640x350.jpg" team="" teleworks'="" title="Curiosity"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 14, 2020</div>
# <div class="content_title">
# 										  Curiosity's Team Teleworks
# 										</div>
# <div class="article_teaser_body">
# 										  Members of NASAs Curiosity Mars rover mission team photographed themselves on March 20, 2020, the first day the entire mission team worked remotely from home.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a small portion of Olympia Undae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23837_hires.jpg" data-link="/spaceimages/details.php?id=PIA23837" data-thumbnail="/spaceimages/images/wallpaper/PIA23837-640x350.jpg" data-title="Olympia Undae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 14, 2020</h3>
# <div class="item_tease_overlay">Olympia Undae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Olympia Undae" class="thumb" src="/spaceimages/images/wallpaper/PIA23837-640x350.jpg" title="Olympia Undae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 14, 2020</div>
# <div class="content_title">
# 										  Olympia Undae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a small portion of Olympia Undae.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows an unnamed crater in Arabia Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23836_hires.jpg" data-link="/spaceimages/details.php?id=PIA23836" data-thumbnail="/spaceimages/images/wallpaper/PIA23836-640x350.jpg" data-title="Dark Slope Streaks">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 13, 2020</h3>
# <div class="item_tease_overlay">Dark Slope Streaks</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Dark Slope Streaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23836-640x350.jpg" title="Dark Slope Streaks"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 13, 2020</div>
# <div class="content_title">
# 										  Dark Slope Streaks
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows an unnamed crater in Arabia Terra.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Olympia Undae, a vast sand sea near the north pole." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23835_hires.jpg" data-link="/spaceimages/details.php?id=PIA23835" data-thumbnail="/spaceimages/images/wallpaper/PIA23835-640x350.jpg" data-title="Olympia Undae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 10, 2020</h3>
# <div class="item_tease_overlay">Olympia Undae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Olympia Undae" class="thumb" src="/spaceimages/images/wallpaper/PIA23835-640x350.jpg" title="Olympia Undae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 10, 2020</div>
# <div class="content_title">
# 										  Olympia Undae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of Olympia Undae, a vast sand sea near the north pole.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of one of the numerous channels that dissect the northern margin on Arabia Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23834_hires.jpg" data-link="/spaceimages/details.php?id=PIA23834" data-thumbnail="/spaceimages/images/wallpaper/PIA23834-640x350.jpg" data-title="Arabia Terra Channel">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 9, 2020</h3>
# <div class="item_tease_overlay">Arabia Terra Channel</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Arabia Terra Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23834-640x350.jpg" title="Arabia Terra Channel"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 9, 2020</div>
# <div class="content_title">
# 										  Arabia Terra Channel
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of one of the numerous channels that dissect the northern margin on Arabia Terra.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows Olympia Undae during north polar summer." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23833_hires.jpg" data-link="/spaceimages/details.php?id=PIA23833" data-thumbnail="/spaceimages/images/wallpaper/PIA23833-640x350.jpg" data-title="Olympia Undae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 8, 2020</h3>
# <div class="item_tease_overlay">Olympia Undae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Olympia Undae" class="thumb" src="/spaceimages/images/wallpaper/PIA23833-640x350.jpg" title="Olympia Undae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 8, 2020</div>
# <div class="content_title">
# 										  Olympia Undae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows Olympia Undae during north polar summer.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows Inuvik Crater. Located near the north polar cap, this crater is 20 km (12 miles) in diameter." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23832_hires.jpg" data-link="/spaceimages/details.php?id=PIA23832" data-thumbnail="/spaceimages/images/wallpaper/PIA23832-640x350.jpg" data-title="Inuvik Crater Dunes">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 7, 2020</h3>
# <div class="item_tease_overlay">Inuvik Crater Dunes</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Inuvik Crater Dunes" class="thumb" src="/spaceimages/images/wallpaper/PIA23832-640x350.jpg" title="Inuvik Crater Dunes"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 7, 2020</div>
# <div class="content_title">
# 										  Inuvik Crater Dunes
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows Inuvik Crater. Located near the north polar cap, this crater is 20 km (12 miles) in diameter.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 4, 2020 by NASAs Mars Reconnaissance Orbiter, shows gullies are common on steep slopes of many impact craters on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23850_hires.jpg" data-link="/spaceimages/details.php?id=PIA23850" data-thumbnail="/spaceimages/images/wallpaper/PIA23850-640x350.jpg" data-title="Monitoring Active Gullies">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 6, 2020</h3>
# <div class="item_tease_overlay">Monitoring Active Gullies</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Monitoring Active Gullies" class="thumb" src="/spaceimages/images/wallpaper/PIA23850-640x350.jpg" title="Monitoring Active Gullies"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 6, 2020</div>
# <div class="content_title">
# 										  Monitoring Active Gullies
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 4, 2020 by NASAs Mars Reconnaissance Orbiter, shows gullies are common on steep slopes of many impact craters on Mars.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on March 14, 2020 by NASAs Mars Reconnaissance Orbiter, shows an area on Mars with both star and barchan dunes next to each other." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23849_hires.jpg" data-link="/spaceimages/details.php?id=PIA23849" data-thumbnail="/spaceimages/images/wallpaper/PIA23849-640x350.jpg" data-title="Where the Wind Blows">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 6, 2020</h3>
# <div class="item_tease_overlay">Where the Wind Blows</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Where the Wind Blows" class="thumb" src="/spaceimages/images/wallpaper/PIA23849-640x350.jpg" title="Where the Wind Blows"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 6, 2020</div>
# <div class="content_title">
# 										  Where the Wind Blows
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on March 14, 2020 by NASAs Mars Reconnaissance Orbiter, shows an area on Mars with both star and barchan dunes next to each other.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on December 30, 2019 by NASAs Mars Reconnaissance Orbiter, shows Tooting Crater, one of the youngest craters on Mars that is larger than 20-kilometers in diameter." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23848_hires.jpg" data-link="/spaceimages/details.php?id=PIA23848" data-thumbnail="/spaceimages/images/wallpaper/PIA23848-640x350.jpg" data-title="Pitted Material from Tooting Crater">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 6, 2020</h3>
# <div class="item_tease_overlay">Pitted Material from Tooting Crater</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Pitted Material from Tooting Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23848-640x350.jpg" title="Pitted Material from Tooting Crater"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 6, 2020</div>
# <div class="content_title">
# 										  Pitted Material from Tooting Crater
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on December 30, 2019 by NASAs Mars Reconnaissance Orbiter, shows Tooting Crater, one of the youngest craters on Mars that is larger than 20-kilometers in diameter.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image acquired on February 2, 2020 by NASAs Mars Reconnaissance Orbiter, shows the inside of an impact crater on the northern plains of Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23847_hires.jpg" data-link="/spaceimages/details.php?id=PIA23847" data-thumbnail="/spaceimages/images/wallpaper/PIA23847-640x350.jpg" data-title="Colorful Bedrock in a Northern Plains Crater">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 6, 2020</h3>
# <div class="item_tease_overlay">Colorful Bedrock in a Northern Plains Crater</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Colorful Bedrock in a Northern Plains Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23847-640x350.jpg" title="Colorful Bedrock in a Northern Plains Crater"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 6, 2020</div>
# <div class="content_title">
# 										  Colorful Bedrock in a Northern Plains Crater
# 										</div>
# <div class="article_teaser_body">
# 										  This image acquired on February 2, 2020 by NASAs Mars Reconnaissance Orbiter, shows the inside of an impact crater on the northern plains of Mars.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of an unnamed channel in Tyrrhena Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23831_hires.jpg" data-link="/spaceimages/details.php?id=PIA23831" data-thumbnail="/spaceimages/images/wallpaper/PIA23831-640x350.jpg" data-title="Channel">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 6, 2020</h3>
# <div class="item_tease_overlay">Channel</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Channel" class="thumb" src="/spaceimages/images/wallpaper/PIA23831-640x350.jpg" title="Channel"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 6, 2020</div>
# <div class="content_title">
# 										  Channel
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a section of an unnamed channel in Tyrrhena Terra.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows windstreaks located in Daedalia Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23820_hires.jpg" data-link="/spaceimages/details.php?id=PIA23820" data-thumbnail="/spaceimages/images/wallpaper/PIA23820-640x350.jpg" data-title="Windstreaks">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 3, 2020</h3>
# <div class="item_tease_overlay">Windstreaks</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Windstreaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23820-640x350.jpg" title="Windstreaks"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 3, 2020</div>
# <div class="content_title">
# 										  Windstreaks
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows windstreaks located in Daedalia Planum.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows dunes on the floor of Orson Welles Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23819_hires.jpg" data-link="/spaceimages/details.php?id=PIA23819" data-thumbnail="/spaceimages/images/wallpaper/PIA23819-640x350.jpg" data-title="Orson Welles Crater Dunes">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 2, 2020</h3>
# <div class="item_tease_overlay">Orson Welles Crater Dunes</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Orson Welles Crater Dunes" class="thumb" src="/spaceimages/images/wallpaper/PIA23819-640x350.jpg" title="Orson Welles Crater Dunes"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 2, 2020</div>
# <div class="content_title">
# 										  Orson Welles Crater Dunes
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows dunes on the floor of Orson Welles Crater.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the summit caldera of Olympus Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23818_hires.jpg" data-link="/spaceimages/details.php?id=PIA23818" data-thumbnail="/spaceimages/images/wallpaper/PIA23818-640x350.jpg" data-title="Olympus Mons Summit">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">April 1, 2020</h3>
# <div class="item_tease_overlay">Olympus Mons Summit</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Olympus Mons Summit" class="thumb" src="/spaceimages/images/wallpaper/PIA23818-640x350.jpg" title="Olympus Mons Summit"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">April 1, 2020</div>
# <div class="content_title">
# 										  Olympus Mons Summit
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of the summit caldera of Olympus Mons.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows Melas Chasma. The linear and arcuate features at the top of the image are on the surface of a large landslide." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23817_hires.jpg" data-link="/spaceimages/details.php?id=PIA23817" data-thumbnail="/spaceimages/images/wallpaper/PIA23817-640x350.jpg" data-title="Melas Chasma">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">March 31, 2020</h3>
# <div class="item_tease_overlay">Melas Chasma</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Melas Chasma" class="thumb" src="/spaceimages/images/wallpaper/PIA23817-640x350.jpg" title="Melas Chasma"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">March 31, 2020</div>
# <div class="content_title">
# 										  Melas Chasma
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows Melas Chasma. The linear and arcuate features at the top of the image are on the surface of a large landslide.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the inner rim of an unnamed crater in southern Arabia Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23816_hires.jpg" data-link="/spaceimages/details.php?id=PIA23816" data-thumbnail="/spaceimages/images/wallpaper/PIA23816-640x350.jpg" data-title="Dark Slope Streaks">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">March 30, 2020</h3>
# <div class="item_tease_overlay">Dark Slope Streaks</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Dark Slope Streaks" class="thumb" src="/spaceimages/images/wallpaper/PIA23816-640x350.jpg" title="Dark Slope Streaks"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">March 30, 2020</div>
# <div class="content_title">
# 										  Dark Slope Streaks
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows part of the inner rim of an unnamed crater in southern Arabia Terra.
# 										</div>
# </div>
# </div>
# </a>, <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a small portion of Tempe Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23815_hires.jpg" data-link="/spaceimages/details.php?id=PIA23815" data-thumbnail="/spaceimages/images/wallpaper/PIA23815-640x350.jpg" data-title="Tempe Fossae">
# <div class="image_and_description_container">
# <div class="rollover_description">
# <h3 class="release_date">March 27, 2020</h3>
# <div class="item_tease_overlay">Tempe Fossae</div>
# <div class="overlay_arrow">
# <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
# </div>
# </div>
# <div class="img">
# <img alt="Tempe Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23815-640x350.jpg" title="Tempe Fossae"/>
# </div>
# <div class="list_text_content">
# <div class="article_teaser_body">March 27, 2020</div>
# <div class="content_title">
# 										  Tempe Fossae
# 										</div>
# <div class="article_teaser_body">
# 										  This image from NASAs Mars Odyssey shows a small portion of Tempe Fossae.
# 										</div>
# </div>
# </div>
# </a>]

# %%
#  getting the featured_image_url and appending to the image printed

#create an empty list

img_src = []
for image in img:
   full_image = image['data-fancybox-href']
   img_src.append(full_image)

featured_image_url = 'https://www.jpl.nasa.gov' + full_image

# check
featured_image_url
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA23815_hires.jpg'

# %%
# Mars Facts

# %%
url = 'https://space-facts.com/mars/'

# %%
# to get all tables 
tables_df = pd.read_html(url)
tables_df
# Out:
# [                      0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers,
#    Mars - Earth Comparison             Mars            Earth
#  0               Diameter:         6,779 km        12,742 km
#  1                   Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
#  2                  Moons:                2                1
#  3      Distance from Sun:   227,943,824 km   149,598,262 km
#  4         Length of Year:   687 Earth days      365.24 days
#  5            Temperature:    -153 to 20 °C      -88 to 58°C,
#                        0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:            2 (Phobos & Deimos)
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers]

# %%
# get the required table and its DF


mars_facts=tables_df[0]

#rename columns of the table

mars_facts.columns = ["Description","Fact Value"]
mars_facts
# Out:
#             Description                     Fact Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
#pandas to html

html_table = mars_facts.to_html()
html_table

html_table=html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Description</th>      <th>Fact Value</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>Equatorial Diameter:</td>      <td>6,792 km</td>    </tr>    <tr>      <th>1</th>      <td>Polar Diameter:</td>      <td>6,752 km</td>    </tr>    <tr>      <th>2</th>      <td>Mass:</td>      <td>6.39 × 10^23 kg (0.11 Earths)</td>    </tr>    <tr>      <th>3</th>      <td>Moons:</td>      <td>2 (Phobos &amp; Deimos)</td>    </tr>    <tr>      <th>4</th>      <td>Orbit Distance:</td>      <td>227,943,824 km (1.38 AU)</td>    </tr>    <tr>      <th>5</th>      <td>Orbit Period:</td>      <td>687 days (1.9 years)</td>    </tr>    <tr>      <th>6</th>      <td>Surface Temperature:</td>      <td>-87 to -5 °C</td>    </tr>    <tr>      <th>7</th>      <td>First Record:</td>      <td>2nd millennium BC</td>    </tr>    <tr>      <th>8</th>      <td>Recorded By:</td>      <td>Egyptian astronomers</td>    </tr>  </tbody></table>'

# %%
# saving to a table html

mars_facts.to_html('table.html')

# %% [markdown]
#  Mars Hemispheres

# %%
# Visit the USGS Astrogeology site here to obtain high resolution images for each of Mar's hemispheres.


#Url to scrape
url_mars_hems='https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'

# %%
# visiting the browser

browser.visit(url_mars_hems)

html_3= browser.html

#getting the soup object
soup_3 = BeautifulSoup(html_3, 'html.parser')

# %%
# getting the titles of the hemispheres
cerberus_hem = browser.find_by_tag('h3')[0].text
schiaparelli_hem= browser.find_by_tag('h3')[0].text
syrtis_hem = browser.find_by_tag('h3')[0].text
valles_hem = browser.find_by_tag('h3')[0].text

# testing
cerberus_hem
# Out:
# 'Cerberus Hemisphere Enhanced'

# %%
#getting the images

browser.click_link_by_partial_text('Cerberus Hemisphere Enhanced')

# %%
html_4=browser.html
soup_4=BeautifulSoup(html_4, 'html.parser')

# %%
cerbus=soup_4.find_all('a')[5]['href']

# %%
browser.back()

# %%
browser.click_link_by_partial_text('Schiaparelli Hemisphere Enhanced')
html_4=browser.html
soup_4=BeautifulSoup(html_4, 'html.parser')

# %%
schia=soup_4.find_all('a')[5]['href']

# %%
browser.back()

# %%
browser.click_link_by_partial_text('Syrtis Major Hemisphere Enhanced')
html_4=browser.html
soup_4=BeautifulSoup(html_4, 'html.parser')

# %%
cerbus
# Out:
# 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif'

# %%
syrtis=soup_4.find_all('a')[5]['href']

# %%
browser.back()

# %%
browser.click_link_by_partial_text('Valles Marineris Hemisphere Enhanced')
html_4=browser.html
soup_4=BeautifulSoup(html_4, 'html.parser')

# %%
valles=soup_4.find_all('a')[5]['href']

# %%
hemisphere_image_urls = [
    {"title": cerberus_hem, "img_url": cerbus},
    {"title": schiaparelli_hem, "img_url": schia},
    {"title": syrtis_hem, "img_url": syrtis},
    {"title": valles_hem, "img_url": valles},
]

# %%
print(hemisphere_image_urls)
# Out:
# [{'title': 'Cerberus Hemisphere Enhanced', 'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif'}, {'title': 'Cerberus Hemisphere Enhanced', 'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif'}, {'title': 'Cerberus Hemisphere Enhanced', 'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif'}, {'title': 'Cerberus Hemisphere Enhanced', 'img_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif'}]
